# %% [markdown]
# ## Sign language translation
# #### ANN Network
# #### Author : Gyan Krishna

# %%
from keras.layers import Dense, Flatten, Dropout, Activation
from keras.models import Sequential
from keras.utils import np_utils, plot_model, to_categorical
from sklearn.model_selection import train_test_split

import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

from numpy import argmax
import pydot
import os

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# Num GPUs Available:  1
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-8c9e220007e1> in <module>
#       1 print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# ----> 2 print('Default GPU Device: {}'.format(tf.test.gpu))
#
# AttributeError: module 'tensorflow._api.v2.test' has no attribute 'gpu'

# %% [markdown]
# ## Loading the data set

# %%
model_images_path = os.path.join(os.getcwd(),r'model_images')
accuracy_plots_path =os.path.join(os.getcwd(), r'accuracy_plots')

npx_path = os.path.join(os.getcwd(), r"npx_dataset")
x_data = np.load(os.path.join(npx_path, "x_data.npy"))
y_data = np.load(os.path.join(npx_path, "y_data.npy"))

print(x_data.shape)
print(y_data.shape)
# Out:
# (87000, 100, 100)
# (87000,)

# %% [markdown]
# ## Splitting the data set

# %%
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size = 0.15)
x_train, x_valid, y_train, y_valid = train_test_split(x_train, y_train, test_size = 0.15)


print("x train shape      : ", x_train.shape)
print("y train shape      : ", y_train.shape)
print("\nx validation shape : ", x_valid.shape)
print("y validation shape : ", y_valid.shape)
print("\nx test shape       : ", x_test.shape)
print("y test shape       : ", y_test.shape)
# Out:
# x train shape      :  (62857, 100, 100)
# y train shape      :  (62857,)
#
# x validation shape :  (11093, 100, 100)
# y validation shape :  (11093,)
#
# x test shape       :  (13050, 100, 100)
# y test shape       :  (13050,)

# %% [markdown]
# ## Normalizing the data set

# %%
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_valid = x_valid.astype('float32')

x_train /= 255
x_test /= 255
x_valid /= 255

# %% [markdown]
# ## Converting y_test and y_train to categorical data

# %%
n_category = 29
y_train = np_utils.to_categorical(y_train, n_category)
y_test  = np_utils.to_categorical(y_test,  n_category)
y_valid = np_utils.to_categorical(y_valid,  n_category)

# %% [markdown]
# ## Creating the base line model

# %%
def baseline_model():
    model = Sequential()
    model.add(Flatten(input_shape = (100, 100)))
    model.add(Dense(650, activation = 'relu'))
    model.add(Dropout(0.2))
    model.add(Dense(350, activation = 'relu'))
    model.add(Dropout(0.2))
    model.add(Dense(29))
    model.add(Activation('softmax'))

    model.summary()
    return model

# %%
model = baseline_model()
plot_model(model,
          to_file = os.path.join(accuracy_plots_path, "ann_baseline.jpg"),
          show_shapes = True,
          show_layer_names = True,
          rankdir = "TB",
          expand_nested = False,
          dpi = 150)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 10000)             0
# _________________________________________________________________
# dense (Dense)                (None, 650)               6500650
# _________________________________________________________________
# dropout (Dropout)            (None, 650)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 350)               227850
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 350)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 29)                10179
# _________________________________________________________________
# activation (Activation)      (None, 29)                0
# =================================================================
# Total params: 6,738,679
# Trainable params: 6,738,679
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss = 'categorical_crossentropy',
             optimizer = 'adam',
             metrics = ['categorical_accuracy'])

# %%
epochs = 100
model_log = model.fit(x_train, y_train, 
                      batch_size = 256, 
                      epochs = 100, 
                      verbose = 1,
                      validation_data = (x_valid, y_valid))
# Out:
# Epoch 1/100
# 246/246 [==============================] - 22s 89ms/step - loss: 3.7893 - categorical_accuracy: 0.0692 - val_loss: 2.5212 - val_categorical_accuracy: 0.2303
# Epoch 60/100
# 246/246 [==============================] - 23s 92ms/step - loss: 1.1737 - categorical_accuracy: 0.5942 - val_loss: 0.9508 - val_categorical_accuracy: 0.6554
# Epoch 61/100
# 246/246 [==============================] - 22s 88ms/step - loss: 1.1600 - categorical_accuracy: 0.6026 - val_loss: 0.9657 - val_categorical_accuracy: 0.6481
# Epoch 62/100
# 246/246 [==============================] - 22s 89ms/step - loss: 1.1646 - categorical_accuracy: 0.6000 - val_loss: 0.9503 - val_categorical_accuracy: 0.6665
# Epoch 63/100
# 246/246 [==============================] - 22s 88ms/step - loss: 1.2050 - categorical_accuracy: 0.5827 - val_loss: 1.2110 - val_categorical_accuracy: 0.5554
# Epoch 64/100
# 246/246 [==============================] - 22s 90ms/step - loss: 1.1688 - categorical_accuracy: 0.5967 - val_loss: 1.0090 - val_categorical_accuracy: 0.6381
# Epoch 65/100
# 246/246 [==============================] - 22s 91ms/step - loss: 1.1194 - categorical_accuracy: 0.6147 - val_loss: 1.1712 - val_categorical_accuracy: 0.5897
# Epoch 66/100
# 246/246 [==============================] - 24s 99ms/step - loss: 1.1522 - categorical_accuracy: 0.6031 - val_loss: 1.0021 - val_categorical_accuracy: 0.6442
# Epoch 67/100
# 246/246 [==============================] - 22s 91ms/step - loss: 1.1161 - categorical_accuracy: 0.6163 - val_loss: 1.0501 - val_categorical_accuracy: 0.6151
# Epoch 68/100
# 246/246 [==============================] - 23s 94ms/step - loss: 1.1392 - categorical_accuracy: 0.6077 - val_loss: 1.2702 - val_categorical_accuracy: 0.5594
# Epoch 69/100
# 246/246 [==============================] - 38s 156ms/step - loss: 1.1365 - categorical_accuracy: 0.6089 - val_loss: 0.9843 - val_categorical_accuracy: 0.6445
# Epoch 70/100
# 246/246 [==============================] - 23s 93ms/step - loss: 1.1375 - categorical_accuracy: 0.6075 - val_loss: 0.8987 - val_categorical_accuracy: 0.6781
# Epoch 71/100
# 246/246 [==============================] - 22s 89ms/step - loss: 1.1145 - categorical_accuracy: 0.6148 - val_loss: 1.1297 - val_categorical_accuracy: 0.5890
# Epoch 72/100
# 246/246 [==============================] - 21s 87ms/step - loss: 1.1549 - categorical_accuracy: 0.6003 - val_loss: 1.2915 - val_categorical_accuracy: 0.5564
# Epoch 73/100
# 246/246 [==============================] - 21s 85ms/step - loss: 1.1236 - categorical_accuracy: 0.6108 - val_loss: 0.9917 - val_categorical_accuracy: 0.6505
# Epoch 74/100
# 246/246 [==============================] - 21s 86ms/step - loss: 1.1095 - categorical_accuracy: 0.6160 - val_loss: 1.0279 - val_categorical_accuracy: 0.6339
# Epoch 75/100
# 246/246 [==============================] - 21s 85ms/step - loss: 1.1163 - categorical_accuracy: 0.6192 - val_loss: 1.0349 - val_categorical_accuracy: 0.6239
# Epoch 76/100
# 246/246 [==============================] - 22s 88ms/step - loss: 1.1486 - categorical_accuracy: 0.6057 - val_loss: 1.0344 - val_categorical_accuracy: 0.6189
# Epoch 77/100
# 246/246 [==============================] - 20s 82ms/step - loss: 1.0890 - categorical_accuracy: 0.6243 - val_loss: 1.1351 - val_categorical_accuracy: 0.6022
# Epoch 78/100
# 246/246 [==============================] - 22s 88ms/step - loss: 1.1138 - categorical_accuracy: 0.6152 - val_loss: 0.9667 - val_categorical_accuracy: 0.6498
# Epoch 79/100
# 246/246 [==============================] - 23s 92ms/step - loss: 1.0911 - categorical_accuracy: 0.6254 - val_loss: 1.0395 - val_categorical_accuracy: 0.6177
# Epoch 80/100
# 246/246 [==============================] - 23s 94ms/step - loss: 1.1331 - categorical_accuracy: 0.6120 - val_loss: 1.0360 - val_categorical_accuracy: 0.6214
# Epoch 81/100
# 246/246 [==============================] - 25s 102ms/step - loss: 1.0850 - categorical_accuracy: 0.6248 - val_loss: 1.0942 - val_categorical_accuracy: 0.5924
# Epoch 82/100
# 246/246 [==============================] - 22s 91ms/step - loss: 1.0878 - categorical_accuracy: 0.6269 - val_loss: 1.0150 - val_categorical_accuracy: 0.6304
# Epoch 83/100
# 246/246 [==============================] - 22s 90ms/step - loss: 1.0943 - categorical_accuracy: 0.6219 - val_loss: 0.9017 - val_categorical_accuracy: 0.6694
# Epoch 84/100
# 246/246 [==============================] - 23s 92ms/step - loss: 1.1010 - categorical_accuracy: 0.6200 - val_loss: 1.0479 - val_categorical_accuracy: 0.6135
# Epoch 85/100
# 246/246 [==============================] - 23s 94ms/step - loss: 1.1199 - categorical_accuracy: 0.6147 - val_loss: 1.1813 - val_categorical_accuracy: 0.5897
# Epoch 86/100
# 246/246 [==============================] - 23s 93ms/step - loss: 1.0951 - categorical_accuracy: 0.6236 - val_loss: 1.0634 - val_categorical_accuracy: 0.6219
# Epoch 87/100
# 246/246 [==============================] - 23s 93ms/step - loss: 1.0754 - categorical_accuracy: 0.6296 - val_loss: 1.2423 - val_categorical_accuracy: 0.5531
# Epoch 88/100
# 246/246 [==============================] - 23s 93ms/step - loss: 1.0977 - categorical_accuracy: 0.6193 - val_loss: 1.2105 - val_categorical_accuracy: 0.5720
# Epoch 89/100
# 246/246 [==============================] - 22s 89ms/step - loss: 1.0810 - categorical_accuracy: 0.6247 - val_loss: 1.0994 - val_categorical_accuracy: 0.5950
# Epoch 90/100
# 246/246 [==============================] - 22s 90ms/step - loss: 1.0842 - categorical_accuracy: 0.6243 - val_loss: 1.2583 - val_categorical_accuracy: 0.5583
# Epoch 91/100
# 246/246 [==============================] - 22s 88ms/step - loss: 1.0484 - categorical_accuracy: 0.6406 - val_loss: 1.2397 - val_categorical_accuracy: 0.5787
# Epoch 92/100
# 246/246 [==============================] - 23s 93ms/step - loss: 1.0554 - categorical_accuracy: 0.6351 - val_loss: 1.0101 - val_categorical_accuracy: 0.6277
# Epoch 93/100
# 246/246 [==============================] - 22s 91ms/step - loss: 1.0404 - categorical_accuracy: 0.6401 - val_loss: 1.0490 - val_categorical_accuracy: 0.6171
# Epoch 94/100
# 246/246 [==============================] - 22s 90ms/step - loss: 1.1117 - categorical_accuracy: 0.6197 - val_loss: 1.2451 - val_categorical_accuracy: 0.5741
# Epoch 95/100
# 246/246 [==============================] - 22s 90ms/step - loss: 1.1576 - categorical_accuracy: 0.6088 - val_loss: 1.1572 - val_categorical_accuracy: 0.6049
# Epoch 96/100
# 246/246 [==============================] - 23s 93ms/step - loss: 1.1396 - categorical_accuracy: 0.6116 - val_loss: 1.1642 - val_categorical_accuracy: 0.5941
# Epoch 97/100
# 246/246 [==============================] - 22s 89ms/step - loss: 1.1876 - categorical_accuracy: 0.5958 - val_loss: 1.2680 - val_categorical_accuracy: 0.5689
# Epoch 98/100
# 246/246 [==============================] - 20s 83ms/step - loss: 1.1627 - categorical_accuracy: 0.6049 - val_loss: 1.1270 - val_categorical_accuracy: 0.5942
# Epoch 99/100
# 246/246 [==============================] - 20s 83ms/step - loss: 1.1221 - categorical_accuracy: 0.6197 - val_loss: 1.1672 - val_categorical_accuracy: 0.5971
# Epoch 100/100
# 246/246 [==============================] - 21s 83ms/step - loss: 1.1097 - categorical_accuracy: 0.6252 - val_loss: 1.4327 - val_categorical_accuracy: 0.5424

# %%
def evaluate_model(model, model_log, model_name):
    #print(model_log.history['loss'])
    print("train loss = ", model_log.history['loss'][-1])
    print("train accuracy = ", model_log.history['accuracy'][-1])
          
    print("test loss = ", model_log.history['val_loss'][-1])
    print("test accuracy = ", model_log.history['val_accuracy'][-1])

    plt.subplot(2,1,1)
    plt.title(model_name+' accuracy')
    plt.plot(range(1, epochs+1), model_log.history['accuracy'])
    plt.plot(range(1,  epochs+1), model_log.history['val_accuracy'])
    
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='lower right')
    
    plt.subplot(2,1,2)
    plt.title(model_name+' loss')
    plt.plot(model_log.history['loss'])
    plt.plot(model_log.history['val_loss'])
    
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['loss', 'test'], loc='lower right')
    
    plt.tight_layout()
    
    plt.savefig(os.path.join(model_images_path, model_name+"model softmax 1000-650-350-29.jpg"))
    return

# %%
evaluate_model(model, model_log, "base line")
# Out:
# train loss =  1.1275482177734375
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-118a9ff24983> in <module>
# ----> 1 evaluate_model(model, model_log, "base line")
#
# <ipython-input-12-4c66bd855224> in evaluate_model(model, model_log, model_name)
#       2     #print(model_log.history['loss'])
#       3     print("train loss = ", model_log.history['loss'][-1])
# ----> 4     print("train accuracy = ", model_log.history['accuracy'][-1])
#       5
#       6     print("test loss = ", model_log.history['val_loss'][-1])
#
# KeyError: 'accuracy'

# %% [markdown]
# # Evaluating testing data

# %%
results = model.evaluate(x_test, y_test, batch_size = 256)
print("\n\n test loss, test accuracy = ",results)

# %%
y_pred = []
count = 0
for i in range(len(x_test)):
    test = np.expand_dims(x_test[i], 0)
    pred = model.predict_classes(test)
    #print(pred)
    #print(argmax(y_test[i]))
    if(pred == argmax(y_test[i])):
        count += 1
    #plt.imshow(x_test[i], cmap = 'gray')
    #plt.show()
print(count)
print(len(x_test))

# %%
fig, ax = plt.subplots(5,5,sharex=True,sharey=True,figsize = (100,100))
for i, axis in enumerate(ax.flat):
    axis.imshow(x_test[i],cmap = "gray",interpolation = "nearest")
    
    test = np.expand_dims(x_test[i], 0)
    pred = model.predict_classes(test)
    axis.set_title(str(pred))
plt.show()
