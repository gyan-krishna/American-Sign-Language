# %% [markdown]
# ## Sign language translation
# #### ANN Network
# #### Author : Gyan Krishna

# %%
from keras.layers import Dense, Flatten, Dropout, Activation
from keras.models import Sequential
from keras.utils import np_utils, plot_model, to_categorical
from keras.callbacks import Callback
from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt
import numpy as np

from numpy import argmax
import pydot
import os

# %% [markdown]
# ## Loading the data set

# %%
npx_path = os.path.join(os.getcwd(), r"npx_dataset")
x_data = np.load(os.path.join(npx_path, "x_data.npy"))
y_data = np.load(os.path.join(npx_path, "y_data.npy"))

print(x_data.shape)
print(y_data.shape)
# Out:
# (87000, 100, 100)
# (87000,)

# %% [markdown]
# ## Splitting the data set

# %%
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size = 0.15)
x_train, x_valid, y_train, y_valid = train_test_split(x_train, y_train, test_size = 0.15)


print("x train shape      : ", x_train.shape)
print("y train shape      : ", y_train.shape)
print("x validation shape : ", x_valid.shape)
print("y validation shape : ", y_valid.shape)
print("x test shape       : ", x_test.shape)
print("y test shape       : ", y_test.shape)
# Out:
# x train shape      :  (62857, 100, 100)
# y train shape      :  (62857,)
# x validation shape :  (11093, 100, 100)
# y validation shape :  (11093,)
# x test shape       :  (13050, 100, 100)
# y test shape       :  (13050,)

# %% [markdown]
# ## Normalizing the data set

# %%
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_valid = x_valid.astype('float32')

x_train /= 255
x_test /= 255
x_valid /= 255

# %% [markdown]
# ## Converting y_test and y_train to categorical data

# %%
n_category = 29
y_train = np_utils.to_categorical(y_train, n_category)
y_test  = np_utils.to_categorical(y_test,  n_category)
y_valid = np_utils.to_categorical(y_valid,  n_category)

# %% [markdown]
# ## Creating the base line model

# %%
def baseline_model():
    model = Sequential()
    model.add(Flatten(input_shape = (100, 100)))
    model.add(Dense(650, activation = 'relu'))
    model.add(Dropout(0.2))
    model.add(Dense(350, activation = 'relu'))
    model.add(Dropout(0.2))
    model.add(Dense(29))
    model.add(Activation('softmax'))

    model.summary()
    return model

# %%
model = baseline_model()
plot_model(model,
          to_file = "ann_baseline.jpg",
          show_shapes = True,
          show_layer_names = True,
          rankdir = "TB",
          expand_nested = False,
          dpi = 150)
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_8 (Flatten)          (None, 10000)             0
# _________________________________________________________________
# dense_11 (Dense)             (None, 650)               6500650
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 650)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 350)               227850
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 350)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 29)                10179
# _________________________________________________________________
# activation_8 (Activation)    (None, 29)                0
# =================================================================
# Total params: 6,738,679
# Trainable params: 6,738,679
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss = 'categorical_crossentropy',
             optimizer = 'adam',
             metrics = ['accuracy'])

# %%
epochs = 100
model_log = model.fit(x_train, y_train, 
                      batch_size = 256, 
                      epochs = 100, 
                      verbose = 1,
                      validation_data = (x_valid, y_valid))
# Out:
# Epoch 1/100
# 246/246 [==============================] - 21s 81ms/step - loss: 3.7841 - accuracy: 0.0812 - val_loss: 2.4406 - val_accuracy: 0.2566
# Epoch 2/100
# 246/246 [==============================] - 20s 80ms/step - loss: 2.5105 - accuracy: 0.2117 - val_loss: 2.0562 - val_accuracy: 0.3520
# Epoch 3/100
# 246/246 [==============================] - 20s 81ms/step - loss: 2.2496 - accuracy: 0.2734 - val_loss: 1.7550 - val_accuracy: 0.4434
# Epoch 4/100
# 246/246 [==============================] - 20s 82ms/step - loss: 2.0015 - accuracy: 0.3339 - val_loss: 1.5645 - val_accuracy: 0.5108
# Epoch 88/100
# 246/246 [==============================] - 21s 86ms/step - loss: 0.8011 - accuracy: 0.7180 - val_loss: 0.5868 - val_accuracy: 0.7958
# Epoch 89/100
# 246/246 [==============================] - 21s 85ms/step - loss: 0.8025 - accuracy: 0.7155 - val_loss: 0.6352 - val_accuracy: 0.7683
# Epoch 90/100
# 246/246 [==============================] - 21s 85ms/step - loss: 0.7957 - accuracy: 0.7202 - val_loss: 0.6621 - val_accuracy: 0.7616
# Epoch 91/100
# 246/246 [==============================] - 21s 86ms/step - loss: 0.7930 - accuracy: 0.7181 - val_loss: 0.7758 - val_accuracy: 0.7228
# Epoch 92/100
# 246/246 [==============================] - 21s 86ms/step - loss: 0.7753 - accuracy: 0.7274 - val_loss: 0.6166 - val_accuracy: 0.7871
# Epoch 93/100
# 246/246 [==============================] - 22s 90ms/step - loss: 0.7623 - accuracy: 0.7301 - val_loss: 0.6094 - val_accuracy: 0.7917
# Epoch 94/100
# 246/246 [==============================] - 21s 86ms/step - loss: 0.7576 - accuracy: 0.7335 - val_loss: 0.5475 - val_accuracy: 0.8138
# Epoch 95/100
# 246/246 [==============================] - 21s 83ms/step - loss: 0.7662 - accuracy: 0.7274 - val_loss: 0.6965 - val_accuracy: 0.7580
# Epoch 96/100
# 246/246 [==============================] - 21s 84ms/step - loss: 0.7896 - accuracy: 0.7231 - val_loss: 0.8577 - val_accuracy: 0.6807
# Epoch 97/100
# 246/246 [==============================] - 21s 86ms/step - loss: 0.7651 - accuracy: 0.7286 - val_loss: 0.6887 - val_accuracy: 0.7482
# Epoch 98/100
# 246/246 [==============================] - 21s 86ms/step - loss: 0.7856 - accuracy: 0.7190 - val_loss: 0.7268 - val_accuracy: 0.7508
# Epoch 99/100
# 246/246 [==============================] - 21s 84ms/step - loss: 0.7730 - accuracy: 0.7293 - val_loss: 0.8130 - val_accuracy: 0.7200
# Epoch 100/100
# 246/246 [==============================] - 21s 85ms/step - loss: 0.7740 - accuracy: 0.7269 - val_loss: 0.6755 - val_accuracy: 0.7533

# %%
def evaluate_model(model, model_log, model_name):
    #print(model_log.history['loss'])
    print("train loss = ", model_log.history['loss'][-1])
    print("train accuracy = ", model_log.history['accuracy'][-1])
          
    print("test loss = ", model_log.history['val_loss'][-1])
    print("test accuracy = ", model_log.history['val_accuracy'][-1])

    plt.subplot(2,1,1)
    plt.title(model_name+' accuracy')
    plt.plot(range(1, epochs+1), model_log.history['accuracy'])
    plt.plot(range(1,  epochs+1), model_log.history['val_accuracy'])
    
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='lower right')
    
    plt.subplot(2,1,2)
    plt.title(model_name+' loss')
    plt.plot(model_log.history['loss'])
    plt.plot(model_log.history['val_loss'])
    
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['loss', 'test'], loc='lower right')
    
    plt.tight_layout()
    
    plt.savefig(model_name+" model.jpg")
    return

# %%
evaluate_model(model, model_log, "base line")
# Out:
# train loss =  0.7661497592926025
# train accuracy =  0.7293857336044312
# test loss =  0.6755302548408508
# test accuracy =  0.7532678246498108
