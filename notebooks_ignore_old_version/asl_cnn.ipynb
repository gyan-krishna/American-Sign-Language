# %%
from keras.layers import Dense, Conv2D, MaxPooling2D, Flatten
from keras.models import Sequential
from keras.utils import np_utils, plot_model, to_categorical
from keras.callbacks import Callback

from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import os
import pydot

# %% [markdown]
# ## Checking the gpu being used

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))

#tf.debugging.set_log_device_placement(False)
# Out:
# Num GPUs Available:  1
# Default GPU Device: /device:GPU:0

# %% [markdown]
# ## Loading the data set

# %%
model_images_path = os.path.join(os.getcwd(),r'model_images')
accuracy_plots_path =os.path.join(os.getcwd(), r'accuracy_plots')

npx_path = os.path.join(os.getcwd(), r"npx_dataset")
x_data = np.load(os.path.join(npx_path, "x_data.npy"))
y_data = np.load(os.path.join(npx_path, "y_data.npy"))

x_data = np.expand_dims(np.array(x_data), axis=3)

print(x_data.shape)
print(y_data.shape)
# Out:
# (87000, 100, 100, 1)
# (87000,)

# %% [markdown]
# ## Splitting the dataset

# %%
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size = 0.15)
x_train, x_valid, y_train, y_valid = train_test_split(x_train, y_train, test_size = 0.15)


print("x train shape      : ", x_train.shape)
print("y train shape      : ", y_train.shape)
print("\nx validation shape : ", x_valid.shape)
print("y validation shape : ", y_valid.shape)
print("\nx test shape       : ", x_test.shape)
print("y test shape       : ", y_test.shape)
# Out:
# x train shape      :  (62857, 100, 100, 1)
# y train shape      :  (62857,)
#
# x validation shape :  (11093, 100, 100, 1)
# y validation shape :  (11093,)
#
# x test shape       :  (13050, 100, 100, 1)
# y test shape       :  (13050,)

# %% [markdown]
# ## Normalizing the dataset

# %%
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_valid = x_valid.astype('float32')

x_train /= 255
x_test /= 255
x_valid /= 255

# %% [markdown]
# ## Converting y_test and y_train to categorical data

# %%
y_train = np_utils.to_categorical(y_train, 29)
y_test  = np_utils.to_categorical(y_test,  29)
y_valid = np_utils.to_categorical(y_valid,  29)

# %% [markdown]
# ## Defining the parameters for the model

# %%
labels = ['A', 'B', 'C', 'D', 'del', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'M', 'N', 'nothing', 'O', 'P', 'Q', 'R', 'S', 'space', 'T', 'U', 'V', 'W', 'X', 'Y', 'Z']
batch_size = 256            #batch size while training the model
epochs = 100                #no of traning iterations
n_category = 29             #no of categories
input_shape = (100, 100, 1) #dimensions of the input image
k_size = (3, 3)              #kernel size for cnn

# %%
def baseline_model():
    model = Sequential()
    model.add(Conv2D(32,                     #filters, dimensionality of the output space.
                     kernel_size = k_size,   #kernel size
                     activation = 'relu',    #activation function
                     input_shape = input_shape))     #dimensions of the input layer.    
    model.add(MaxPooling2D(pool_size = (2,2)))
    
    #second cnn layer
    model.add(Conv2D(64,                     #filters, dimensionality of the output space.
                     kernel_size = k_size,   #kernel size
                     activation = 'relu'))    #activation function     
    model.add(MaxPooling2D(pool_size = (2,2)))
    
    model.add(Flatten())
    model.add(Dense(64, activation = 'relu'))
    model.add(Dense(n_category, activation = 'softmax'))
    
    return model

# %%
model = baseline_model()
model.compile(loss = 'categorical_crossentropy',
             optimizer = 'adam',
             metrics = ['Accuracy'])

# %%
model.summary()
plot_model(model,
          to_file = os.path.join(accuracy_plots_path, "cnn_baseline.jpg"),
          show_shapes = True,
          show_layer_names = True,
          rankdir = "TB",
          expand_nested = False,
          dpi = 100)
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_12 (Conv2D)           (None, 98, 98, 32)        320
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 49, 49, 32)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 47, 47, 64)        18496
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 23, 23, 64)        0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 33856)             0
# _________________________________________________________________
# dense_6 (Dense)              (None, 64)                2166848
# _________________________________________________________________
# dense_7 (Dense)              (None, 29)                1885
# =================================================================
# Total params: 2,187,549
# Trainable params: 2,187,549
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_log = model.fit(x_train, y_train,
                     batch_size = batch_size,
                     epochs = epochs,
                     verbose = 1, #provide detailed report after each epoch
                     validation_data = (x_valid, y_valid))
# Out:
# Epoch 1/100
# 246/246 [==============================] - 32s 120ms/step - loss: 2.9999 - accuracy: 0.0000e+00 - val_loss: 1.5452 - val_accuracy: 0.0000e+00
# Epoch 2/100
# 246/246 [==============================] - 28s 115ms/step - loss: 1.2538 - accuracy: 4.5471e-05 - val_loss: 0.8047 - val_accuracy: 3.6370e-04
# Epoch 3/100
# 246/246 [==============================] - 29s 116ms/step - loss: 0.6563 - accuracy: 0.0010 - val_loss: 0.5063 - val_accuracy: 0.0046
# Epoch 4/100
# 246/246 [==============================] - 28s 115ms/step - loss: 0.3968 - accuracy: 0.0056 - val_loss: 0.3329 - val_accuracy: 0.0100
# Epoch 5/100
# 246/246 [==============================] - 28s 116ms/step - loss: 0.2652 - accuracy: 0.0133 - val_loss: 0.2410 - val_accuracy: 0.0202
# Epoch 6/100
# 246/246 [==============================] - 28s 115ms/step - loss: 0.1920 - accuracy: 0.0241 - val_loss: 0.1784 - val_accuracy: 0.0331
# Epoch 7/100
# 246/246 [==============================] - 28s 115ms/step - loss: 0.1375 - accuracy: 0.0379 - val_loss: 0.1441 - val_accuracy: 0.0489
# Epoch 8/100
# 246/246 [==============================] - 29s 116ms/step - loss: 0.0998 - accuracy: 0.0541 - val_loss: 0.1155 - val_accuracy: 0.0638
# Epoch 9/100
# 246/246 [==============================] - 28s 116ms/step - loss: 0.0841 - accuracy: 0.0689 - val_loss: 0.1140 - val_accuracy: 0.0808
# Epoch 10/100
# 246/246 [==============================] - 28s 115ms/step - loss: 0.0666 - accuracy: 0.0857 - val_loss: 0.1247 - val_accuracy: 0.0928
# Epoch 11/100
# 246/246 [==============================] - 28s 115ms/step - loss: 0.0621 - accuracy: 0.1000 - val_loss: 0.1299 - val_accuracy: 0.1087
# Epoch 12/100
# 246/246 [==============================] - 28s 115ms/step - loss: 0.0681 - accuracy: 0.1151 - val_loss: 0.0697 - val_accuracy: 0.1271
# Epoch 13/100
# 246/246 [==============================] - 28s 115ms/step - loss: 0.0426 - accuracy: 0.1341 - val_loss: 0.0696 - val_accuracy: 0.1452
# Epoch 14/100
# 246/246 [==============================] - 28s 115ms/step - loss: 0.0449 - accuracy: 0.1488 - val_loss: 0.0894 - val_accuracy: 0.1478
# Epoch 15/100
# 246/246 [==============================] - 28s 115ms/step - loss: 0.0640 - accuracy: 0.1569 - val_loss: 0.0978 - val_accuracy: 0.1718
# Epoch 16/100
# 246/246 [==============================] - 28s 115ms/step - loss: 0.0309 - accuracy: 0.1755 - val_loss: 0.0629 - val_accuracy: 0.1837
# Epoch 17/100
# 246/246 [==============================] - 28s 115ms/step - loss: 0.0563 - accuracy: 0.1824 - val_loss: 0.0556 - val_accuracy: 0.1935
# Epoch 18/100
# 246/246 [==============================] - 28s 115ms/step - loss: 0.0200 - accuracy: 0.1989 - val_loss: 0.0591 - val_accuracy: 0.2000
# Epoch 19/100
# 246/246 [==============================] - 28s 115ms/step - loss: 0.0253 - accuracy: 0.2066 - val_loss: 0.0481 - val_accuracy: 0.2111
# Epoch 20/100
# 246/246 [==============================] - 28s 115ms/step - loss: 0.0272 - accuracy: 0.2194 - val_loss: 0.0932 - val_accuracy: 0.2163
# Epoch 21/100
# 246/246 [==============================] - 28s 115ms/step - loss: 0.0395 - accuracy: 0.2252 - val_loss: 0.0787 - val_accuracy: 0.2441
# Epoch 22/100
# 246/246 [==============================] - 28s 115ms/step - loss: 0.0384 - accuracy: 0.2402 - val_loss: 0.0690 - val_accuracy: 0.2489
# Epoch 23/100
# 246/246 [==============================] - 28s 115ms/step - loss: 0.0179 - accuracy: 0.2542 - val_loss: 0.0390 - val_accuracy: 0.2590
# Epoch 24/100
# 246/246 [==============================] - 28s 115ms/step - loss: 0.0063 - accuracy: 0.2752 - val_loss: 0.0298 - val_accuracy: 0.2793
# Epoch 25/100
# 246/246 [==============================] - 28s 115ms/step - loss: 0.0046 - accuracy: 0.2873 - val_loss: 0.0204 - val_accuracy: 0.2997
# Epoch 26/100
# 246/246 [==============================] - 28s 115ms/step - loss: 0.0036 - accuracy: 0.3022 - val_loss: 0.0617 - val_accuracy: 0.2930
# Epoch 27/100
# 246/246 [==============================] - 28s 115ms/step - loss: 0.1268 - accuracy: 0.2439 - val_loss: 0.0588 - val_accuracy: 0.2233
# Epoch 28/100
# 246/246 [==============================] - 28s 115ms/step - loss: 0.0199 - accuracy: 0.2261 - val_loss: 0.0271 - val_accuracy: 0.2505
# Epoch 29/100
# 246/246 [==============================] - 28s 115ms/step - loss: 0.0064 - accuracy: 0.2561 - val_loss: 0.0230 - val_accuracy: 0.2628
# Epoch 30/100
# 246/246 [==============================] - 28s 115ms/step - loss: 0.0037 - accuracy: 0.2695 - val_loss: 0.0217 - val_accuracy: 0.2757
# Epoch 31/100
# 246/246 [==============================] - 28s 115ms/step - loss: 0.0032 - accuracy: 0.2810 - val_loss: 0.0191 - val_accuracy: 0.2859
# Epoch 32/100
# 246/246 [==============================] - 28s 115ms/step - loss: 0.0027 - accuracy: 0.2921 - val_loss: 0.0193 - val_accuracy: 0.2966
# Epoch 33/100
# 246/246 [==============================] - 28s 115ms/step - loss: 0.0020 - accuracy: 0.3008 - val_loss: 0.0186 - val_accuracy: 0.3060
# Epoch 34/100
# 246/246 [==============================] - 28s 115ms/step - loss: 0.0017 - accuracy: 0.3133 - val_loss: 0.0180 - val_accuracy: 0.3133
# Epoch 35/100
# 246/246 [==============================] - 28s 115ms/step - loss: 0.0016 - accuracy: 0.3210 - val_loss: 0.0303 - val_accuracy: 0.3135
# Epoch 36/100
# 246/246 [==============================] - 28s 115ms/step - loss: 0.1400 - accuracy: 0.2565 - val_loss: 0.0663 - val_accuracy: 0.2586
# Epoch 37/100
# 246/246 [==============================] - 28s 115ms/step - loss: 0.0217 - accuracy: 0.2719 - val_loss: 0.0348 - val_accuracy: 0.2906
# Epoch 38/100
# 246/246 [==============================] - 28s 115ms/step - loss: 0.0072 - accuracy: 0.2979 - val_loss: 0.0443 - val_accuracy: 0.2980
# Epoch 39/100
# 246/246 [==============================] - 28s 115ms/step - loss: 0.0071 - accuracy: 0.3025 - val_loss: 0.0205 - val_accuracy: 0.3219
# Epoch 40/100
# 246/246 [==============================] - 28s 115ms/step - loss: 0.0018 - accuracy: 0.3293 - val_loss: 0.0189 - val_accuracy: 0.3323
# Epoch 41/100
# 246/246 [==============================] - 28s 115ms/step - loss: 0.0013 - accuracy: 0.3400 - val_loss: 0.0172 - val_accuracy: 0.3448
# Epoch 42/100
# 246/246 [==============================] - 28s 114ms/step - loss: 0.0010 - accuracy: 0.3497 - val_loss: 0.0170 - val_accuracy: 0.3512
# Epoch 43/100
# 246/246 [==============================] - 28s 114ms/step - loss: 7.9885e-04 - accuracy: 0.3580 - val_loss: 0.0181 - val_accuracy: 0.3582
# Epoch 44/100
# 246/246 [==============================] - 28s 114ms/step - loss: 8.2637e-04 - accuracy: 0.3632 - val_loss: 0.0189 - val_accuracy: 0.3644
# Epoch 45/100
# 246/246 [==============================] - 28s 114ms/step - loss: 0.0808 - accuracy: 0.3097 - val_loss: 0.0499 - val_accuracy: 0.2907
# Epoch 46/100
# 246/246 [==============================] - 28s 114ms/step - loss: 0.0096 - accuracy: 0.3013 - val_loss: 0.0455 - val_accuracy: 0.3093
# Epoch 47/100
# 246/246 [==============================] - 28s 114ms/step - loss: 0.0071 - accuracy: 0.3190 - val_loss: 0.0261 - val_accuracy: 0.3277
# Epoch 48/100
# 246/246 [==============================] - 28s 114ms/step - loss: 0.0017 - accuracy: 0.3381 - val_loss: 0.0203 - val_accuracy: 0.3483
# Epoch 49/100
# 246/246 [==============================] - 28s 114ms/step - loss: 0.0011 - accuracy: 0.3527 - val_loss: 0.0193 - val_accuracy: 0.3573
# Epoch 50/100
# 246/246 [==============================] - 28s 114ms/step - loss: 7.8378e-04 - accuracy: 0.3629 - val_loss: 0.0200 - val_accuracy: 0.3651
# Epoch 51/100
# 246/246 [==============================] - 29s 116ms/step - loss: 6.9312e-04 - accuracy: 0.3714 - val_loss: 0.0192 - val_accuracy: 0.3743
# Epoch 52/100
# 246/246 [==============================] - 28s 115ms/step - loss: 5.9626e-04 - accuracy: 0.3795 - val_loss: 0.0185 - val_accuracy: 0.3807
# Epoch 53/100
# 246/246 [==============================] - 28s 115ms/step - loss: 4.8115e-04 - accuracy: 0.3855 - val_loss: 0.0198 - val_accuracy: 0.3879
# Epoch 54/100
# 246/246 [==============================] - 28s 115ms/step - loss: 4.4029e-04 - accuracy: 0.3927 - val_loss: 0.0185 - val_accuracy: 0.3944
# Epoch 55/100
# 246/246 [==============================] - 28s 115ms/step - loss: 3.8514e-04 - accuracy: 0.3989 - val_loss: 0.0183 - val_accuracy: 0.4004
# Epoch 56/100
# 246/246 [==============================] - 28s 115ms/step - loss: 3.3284e-04 - accuracy: 0.4064 - val_loss: 0.0189 - val_accuracy: 0.4010
# Epoch 57/100
# 246/246 [==============================] - 28s 115ms/step - loss: 7.7083e-04 - accuracy: 0.4064 - val_loss: 0.0186 - val_accuracy: 0.4125
# Epoch 58/100
# 246/246 [==============================] - 28s 115ms/step - loss: 2.6143e-04 - accuracy: 0.4179 - val_loss: 0.0180 - val_accuracy: 0.4192
# Epoch 59/100
# 246/246 [==============================] - 28s 115ms/step - loss: 2.2012e-04 - accuracy: 0.4250 - val_loss: 0.0187 - val_accuracy: 0.4237
# Epoch 60/100
# 246/246 [==============================] - 28s 115ms/step - loss: 1.8181e-04 - accuracy: 0.4305 - val_loss: 0.0179 - val_accuracy: 0.4320
# Epoch 61/100
# 246/246 [==============================] - 29s 120ms/step - loss: 0.0013 - accuracy: 0.4353 - val_loss: 0.3529 - val_accuracy: 0.2487
# Epoch 62/100
# 246/246 [==============================] - 28s 115ms/step - loss: 0.2378 - accuracy: 0.2519 - val_loss: 0.0519 - val_accuracy: 0.2909
# Epoch 63/100
# 246/246 [==============================] - 28s 115ms/step - loss: 0.0117 - accuracy: 0.3063 - val_loss: 0.0290 - val_accuracy: 0.3224
# Epoch 64/100
# 246/246 [==============================] - 28s 115ms/step - loss: 0.0034 - accuracy: 0.3313 - val_loss: 0.0201 - val_accuracy: 0.3384
# Epoch 65/100
# 246/246 [==============================] - 28s 115ms/step - loss: 0.0013 - accuracy: 0.3468 - val_loss: 0.0196 - val_accuracy: 0.3541
# Epoch 66/100
# 246/246 [==============================] - 28s 115ms/step - loss: 9.4246e-04 - accuracy: 0.3618 - val_loss: 0.0191 - val_accuracy: 0.3634
# Epoch 67/100
# 246/246 [==============================] - 28s 115ms/step - loss: 7.6581e-04 - accuracy: 0.3690 - val_loss: 0.0185 - val_accuracy: 0.3727
# Epoch 68/100
# 246/246 [==============================] - 28s 115ms/step - loss: 6.3466e-04 - accuracy: 0.3799 - val_loss: 0.0185 - val_accuracy: 0.3800
# Epoch 69/100
# 246/246 [==============================] - 28s 115ms/step - loss: 5.2735e-04 - accuracy: 0.3835 - val_loss: 0.0191 - val_accuracy: 0.3866
# Epoch 70/100
# 246/246 [==============================] - 29s 116ms/step - loss: 4.5251e-04 - accuracy: 0.3946 - val_loss: 0.0186 - val_accuracy: 0.3944
# Epoch 71/100
# 246/246 [==============================] - 28s 115ms/step - loss: 4.1258e-04 - accuracy: 0.4007 - val_loss: 0.0184 - val_accuracy: 0.4001
# Epoch 72/100
# 246/246 [==============================] - 28s 115ms/step - loss: 3.7032e-04 - accuracy: 0.4073 - val_loss: 0.0184 - val_accuracy: 0.4071
# Epoch 73/100
# 246/246 [==============================] - 28s 115ms/step - loss: 3.0238e-04 - accuracy: 0.4141 - val_loss: 0.0192 - val_accuracy: 0.4128
# Epoch 74/100
# 246/246 [==============================] - 28s 115ms/step - loss: 2.8728e-04 - accuracy: 0.4209 - val_loss: 0.0185 - val_accuracy: 0.4186
# Epoch 75/100
# 246/246 [==============================] - 28s 115ms/step - loss: 2.3123e-04 - accuracy: 0.4266 - val_loss: 0.0187 - val_accuracy: 0.4246
# Epoch 76/100
# 246/246 [==============================] - 28s 115ms/step - loss: 2.1337e-04 - accuracy: 0.4309 - val_loss: 0.0192 - val_accuracy: 0.4292
# Epoch 77/100
# 246/246 [==============================] - 28s 115ms/step - loss: 1.8433e-04 - accuracy: 0.4354 - val_loss: 0.0185 - val_accuracy: 0.4362
# Epoch 78/100
# 246/246 [==============================] - 28s 115ms/step - loss: 1.6432e-04 - accuracy: 0.4422 - val_loss: 0.0183 - val_accuracy: 0.4414
# Epoch 79/100
# 246/246 [==============================] - 28s 116ms/step - loss: 1.4250e-04 - accuracy: 0.4455 - val_loss: 0.0183 - val_accuracy: 0.4474
# Epoch 80/100
# 246/246 [==============================] - 28s 116ms/step - loss: 1.3101e-04 - accuracy: 0.4531 - val_loss: 0.0184 - val_accuracy: 0.4527
# Epoch 81/100
# 246/246 [==============================] - 28s 115ms/step - loss: 1.0593e-04 - accuracy: 0.4590 - val_loss: 0.0197 - val_accuracy: 0.4573
# Epoch 82/100
# 246/246 [==============================] - 28s 116ms/step - loss: 1.1904e-04 - accuracy: 0.4621 - val_loss: 0.0192 - val_accuracy: 0.4621
# Epoch 83/100
# 246/246 [==============================] - 28s 116ms/step - loss: 9.3129e-05 - accuracy: 0.4698 - val_loss: 0.0185 - val_accuracy: 0.4681
# Epoch 84/100
# 246/246 [==============================] - 28s 116ms/step - loss: 7.3899e-05 - accuracy: 0.4734 - val_loss: 0.0187 - val_accuracy: 0.4739
# Epoch 85/100
# 246/246 [==============================] - 28s 116ms/step - loss: 6.4006e-05 - accuracy: 0.4797 - val_loss: 0.0189 - val_accuracy: 0.4786
# Epoch 86/100
# 246/246 [==============================] - 28s 116ms/step - loss: 5.9622e-05 - accuracy: 0.4845 - val_loss: 0.0196 - val_accuracy: 0.4792
# Epoch 87/100
# 246/246 [==============================] - 28s 115ms/step - loss: 0.1171 - accuracy: 0.4191 - val_loss: 0.0444 - val_accuracy: 0.3389
# Epoch 88/100
# 246/246 [==============================] - 28s 116ms/step - loss: 0.0098 - accuracy: 0.3500 - val_loss: 0.0384 - val_accuracy: 0.3528
# Epoch 89/100
# 246/246 [==============================] - 28s 115ms/step - loss: 0.0084 - accuracy: 0.3663 - val_loss: 0.0194 - val_accuracy: 0.3770
# Epoch 90/100
# 246/246 [==============================] - 28s 116ms/step - loss: 8.7081e-04 - accuracy: 0.3857 - val_loss: 0.0159 - val_accuracy: 0.3890
# Epoch 91/100
# 246/246 [==============================] - 28s 116ms/step - loss: 5.7139e-04 - accuracy: 0.3948 - val_loss: 0.0148 - val_accuracy: 0.3980
# Epoch 92/100
# 246/246 [==============================] - 28s 116ms/step - loss: 4.6141e-04 - accuracy: 0.4025 - val_loss: 0.0141 - val_accuracy: 0.4057
# Epoch 93/100
# 246/246 [==============================] - 28s 115ms/step - loss: 4.0468e-04 - accuracy: 0.4084 - val_loss: 0.0139 - val_accuracy: 0.4132
# Epoch 94/100
# 246/246 [==============================] - 28s 115ms/step - loss: 3.3926e-04 - accuracy: 0.4184 - val_loss: 0.0143 - val_accuracy: 0.4184
# Epoch 95/100
# 246/246 [==============================] - 28s 116ms/step - loss: 2.8403e-04 - accuracy: 0.4232 - val_loss: 0.0144 - val_accuracy: 0.4251
# Epoch 96/100
# 246/246 [==============================] - 28s 115ms/step - loss: 2.6798e-04 - accuracy: 0.4312 - val_loss: 0.0141 - val_accuracy: 0.4314
# Epoch 97/100
# 246/246 [==============================] - 28s 116ms/step - loss: 2.1723e-04 - accuracy: 0.4370 - val_loss: 0.0141 - val_accuracy: 0.4369
# Epoch 98/100
# 246/246 [==============================] - 28s 115ms/step - loss: 1.8962e-04 - accuracy: 0.4423 - val_loss: 0.0143 - val_accuracy: 0.4421
# Epoch 99/100
# 246/246 [==============================] - 28s 116ms/step - loss: 1.8034e-04 - accuracy: 0.4477 - val_loss: 0.0141 - val_accuracy: 0.4471
# Epoch 100/100
# 246/246 [==============================] - 28s 115ms/step - loss: 1.5526e-04 - accuracy: 0.4511 - val_loss: 0.0149 - val_accuracy: 0.4517

# %%
def evaluate_model(model, model_log, model_name):
    #print(model_log.history['loss'])
    print("train loss = ", model_log.history['loss'][-1])
    print("train accuracy = ", model_log.history['accuracy'][-1])
          
    print("test loss = ", model_log.history['val_loss'][-1])
    print("test accuracy = ", model_log.history['val_accuracy'][-1])

    plt.subplot(2,1,1)
    plt.title(model_name+' accuracy')
    plt.plot(range(1, epochs+1), model_log.history['accuracy'])
    plt.plot(range(1,  epochs+1), model_log.history['val_accuracy'])
    
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='lower right')
    
    plt.subplot(2,1,2)
    plt.title(model_name+' loss')
    plt.plot(model_log.history['loss'])
    plt.plot(model_log.history['val_loss'])
    
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['loss', 'test'], loc='lower right')
    
    plt.tight_layout()
    
    plt.savefig(os.path.join(model_images_path, model_name+"model.jpg"))
    return

# %%
evaluate_model(model, model_log, "base line softmax")
# Out:
# train loss =  0.00015232209989335388
# train accuracy =  0.4538506269454956
# test loss =  0.01490183174610138
# test accuracy =  0.45166102051734924
